# %%
import os
os.makedirs("Data/",exist_ok=True)
os.listdir("Data/")
# Out:
# ['title.basics.tsv.gz', 'title.ratings.tsv.gz', 'title-akas-us-only.csv']

# %%
import pandas as pd
import numpy as np

# %%
basics = pd.read_csv('Data/title.basics.tsv.gz', sep='\t', low_memory=False)

# %%
aka = pd.read_csv('Data/title-akas-us-only.csv', low_memory=False)

# %%
ratings = pd.read_csv('Data/title.ratings.tsv.gz', sep='\t', low_memory=False)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1989
# 1  tt0000002            5.8       264
# 2  tt0000003            6.5      1866
# 3  tt0000004            5.5       177
# 4  tt0000005            6.2      2648

# %%
aka.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %% [markdown]
# # Preprocessing

# %%
filtered_aka = aka[aka['region'] == "US"]
filtered_aka
# Out:
#            titleId  ordering                                      title  \
# 0        tt0000001         6                                 Carmencita
# 1        tt0000002         7                     The Clown and His Dogs
# 2        tt0000005        10                           Blacksmith Scene
# 3        tt0000005         1                        Blacksmithing Scene
# 4        tt0000005         6                        Blacksmith Scene #1
# ...            ...       ...                                        ...
# 1452559  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 1452560  tt9916620         1                          The Copeland Case
# 1452561  tt9916702         1              Loving London: The Playground
# 1452562  tt9916756         1                   Pretty Pretty Black Girl
# 1452563  tt9916764         1                                         38
#
#         region language        types             attributes isOriginalTitle
# 0           US       \N  imdbDisplay                     \N               0
# 1           US       \N           \N  literal English title               0
# 2           US       \N  imdbDisplay                     \N               0
# 3           US       \N  alternative                     \N               0
# 4           US       \N  alternative                     \N               0
# ...        ...      ...          ...                    ...             ...
# 1452559     US       \N  imdbDisplay                     \N               0
# 1452560     US       \N  imdbDisplay                     \N               0
# 1452561     US       \N           \N                     \N               0
# 1452562     US       \N  imdbDisplay                     \N               0
# 1452563     US       \N  imdbDisplay                     \N               0
#
# [1452564 rows x 8 columns]

# %%
# Replacing "\N" with NaN
filtered_aka = filtered_aka.replace({'\\N':np.nan})
filtered_aka
# Out:
#            titleId  ordering                                      title  \
# 0        tt0000001         6                                 Carmencita
# 1        tt0000002         7                     The Clown and His Dogs
# 2        tt0000005        10                           Blacksmith Scene
# 3        tt0000005         1                        Blacksmithing Scene
# 4        tt0000005         6                        Blacksmith Scene #1
# ...            ...       ...                                        ...
# 1452559  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 1452560  tt9916620         1                          The Copeland Case
# 1452561  tt9916702         1              Loving London: The Playground
# 1452562  tt9916756         1                   Pretty Pretty Black Girl
# 1452563  tt9916764         1                                         38
#
#         region language        types             attributes isOriginalTitle
# 0           US      NaN  imdbDisplay                    NaN               0
# 1           US      NaN          NaN  literal English title               0
# 2           US      NaN  imdbDisplay                    NaN               0
# 3           US      NaN  alternative                    NaN               0
# 4           US      NaN  alternative                    NaN               0
# ...        ...      ...          ...                    ...             ...
# 1452559     US      NaN  imdbDisplay                    NaN               0
# 1452560     US      NaN  imdbDisplay                    NaN               0
# 1452561     US      NaN          NaN                    NaN               0
# 1452562     US      NaN  imdbDisplay                    NaN               0
# 1452563     US      NaN  imdbDisplay                    NaN               0
#
# [1452564 rows x 8 columns]

# %%
# Eliminating movies with null runtimeMinutes
basics_filtered = basics.copy()
basics_filtered.dropna(subset=['runtimeMinutes','genres'], inplace=True)
basics_filtered.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
basics_filtered = basics_filtered[basics_filtered['titleType'] == "Movie"]
basics_filtered.head()
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres]
# Index: []

# %%
basics_filtered = basics_filtered['startYear'].astype(float)
basics_filtered.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/_libs/index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'startYear'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 basics_filtered = basics_filtered['startYear'].astype(float)
#       2 basics_filtered.head()
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'startYear'

# %%
basics_filtered = basics_filtered[(basics_filtered['startYear'] >= 2000) & (basics_filtered['startYear'] <= 2021)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/_libs/index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'startYear'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 basics_filtered = basics_filtered[(basics_filtered['startYear'] >= 2000) & (basics_filtered['startYear'] <= 2021)]
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'startYear'
